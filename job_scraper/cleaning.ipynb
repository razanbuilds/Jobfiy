# %%
import json
import pandas as pd

with open('../data/jobs_results_enriched.json', 'r', encoding='utf-8') as f:
    data = json.load(f)

df = pd.json_normalize(data)
print(df.shape)
df.head()
# Out:
# (18, 15)
#     source                                  job_title  \
# 0  JSearch      Senior Technical Standards Consultant
# 1   Jooble                           Systems Engineer
# 2   Jooble  Sales Representative - Cybersecurity SaaS
# 3   Jooble         Senior Backend Engineer - Checkout
# 4   Jooble                 Call Center Representative
#
#                            company          city      location  \
# 0                     Confidential        Riyadh    Riyadh, SA
# 1                    Azeus Convene  Saudi Arabia  Saudi Arabia
# 2                      Beyondtrust  Saudi Arabia  Saudi Arabia
# 3                            Salla  Saudi Arabia  Saudi Arabia
# 4  Maharah Human Resources Company  Saudi Arabia  Saudi Arabia
#
#   employment_type salary skills experience_level  \
# 0       Full-time    N/A      R              N/A
# 1       Full-time           N/A              N/A
# 2       Full-time           N/A              N/A
# 3       Full-time           N/A              N/A
# 4       Full-time           N/A              N/A
#
#                                           apply_link  \
# 0  https://kalamntina.com/vacancies/senior-techni...
# 1         https://jooble.org/jdp/1372804649653381488
# 2          https://jooble.org/jdp/519742607312308554
# 3          https://jooble.org/jdp/927490152558473665
# 4         https://jooble.org/jdp/2995731508694490852
#
#                      posted_at  \
# 0                          NaN
# 1  2026-07-29T08:12:25.8130000
# 2  2026-08-25T08:59:47.4030000
# 3  2026-08-18T19:54:36.0630000
# 4  2026-08-17T22:50:27.0230000
#
#                                          description  \
# 0  Responsibilities\n\r\n\r\n• Lead the developme...
# 1  &nbsp;...project team members in managing syst...
# 2  &nbsp;...meeting or exceeding annual quota \r\...
# 3  &nbsp;...systems problems, building high-perfo...
# 4  &nbsp;...and listening skills. \r\n Ability to...
#
#                                        combined_text extracted_skills  \
# 0  Senior Technical Standards Consultant Responsi...               []
# 1  Systems Engineer &nbsp;...project team members...               []
# 2  Sales Representative - Cybersecurity SaaS &nbs...               []
# 3  Senior Backend Engineer - Checkout &nbsp;...sy...               []
# 4  Call Center Representative &nbsp;...and listen...               []
#
#   final_skills
# 0            R
# 1          N/A
# 2          N/A
# 3          N/A
# 4          N/A

# %%
print(df.columns.tolist())
print(df.dtypes)
df.isnull().sum()
# Out:
# ['source', 'job_title', 'company', 'city', 'location', 'employment_type', 'salary', 'skills', 'experience_level', 'apply_link', 'posted_at', 'description', 'combined_text', 'extracted_skills', 'final_skills']
# source                 str
# job_title              str
# company                str
# city                   str
# location               str
# employment_type        str
# salary                 str
# skills                 str
# experience_level       str
# apply_link             str
# posted_at              str
# description            str
# combined_text          str
# extracted_skills    object
# final_skills           str
# dtype: object
# source              0
# job_title           0
# company             0
# city                0
# location            0
# employment_type     0
# salary              0
# skills              0
# experience_level    0
# apply_link          0
# posted_at           1
# description         0
# combined_text       0
# extracted_skills    0
# final_skills        0
# dtype: int64
